# %% [markdown]
# # Assignment 4

# %%
#installing and importing libraries
# !pip install selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import bs4
from bs4 import BeautifulSoup
import requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# define a function to open an url
def given_url(url):
    global driver
    # first, connect to the webdriver
    driver=webdriver.Chrome(r'chromedriver.exe')
    # maximize window
    driver.maximize_window()
    #enter the url
    driver.get(url)
    delay=10

# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia from given URL

# %%
# give required URL
url= "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
# opening url
given_url(url)    
#creating a blank list to store required data
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#scraping rank from URL
try:
    rank=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")
Rank=Rank[0:30]
Rank

#scraping name from URL
try:
    name=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
    for i in name:
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")
    Name=Name[:-3]
    
#scraping artist from URL
try:
    artist=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("-")
    
#scraping upload date from URL
try:
    upload=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')
    for i in upload:
        Upload_date.append(i.text)
except NoSuchElementException:
    Upload_date.append("-")
    
#scraping views from URL
try:
    views=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')
    for i in views:
        Views.append(i.text)
except NoSuchElementException:
    Views.append("-")
    
# printing length
print(len(Rank),len(Name),len(Artist),len(Upload_date),len(Views))
# Out:
# 30 30 30 30 30

# %%
#making dataframe
df=pd.DataFrame({'Rank':Rank,'Name':Name, 'Artist':Artist,'Upload date':Upload_date,'Views':Views})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.                          "Wheels on the Bus"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %%
driver.close()

# %% [markdown]
# # 2.Scrape the details team India’s international fixtures from bcci.tv.

# %%
# giving url
url= 'https://www.bcci.tv/'
# opening url
given_url(url)

# %%
# click on "menu" button to expand it
#btn=driver.find_element(By.XPATH,'//span[@class="menu-icon__line menu-icon__line-right"]')
#btn.click()

# click on "international" button to expand it
inter=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]')
inter.click()

# %%
# creating empty lists for scraping the data
Match_Title = []
Series = []
Place = []
Date = []
Time = []

#scraping match title
title=driver.find_elements(By.XPATH,'//h5[@class="fix-text"]')
for i in title:
    Match_Title.append(i.text)
    
#scraping series
series = driver.find_elements(By.XPATH,'//div[@class="fixture-card-mid d-flex align-items-center justify-content-between"]') 
for i in series:
    Series.append(i.text)
# scraping place
place=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
for i in place:
    Place.append(i.text)

#scraping time and date
time=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
for i in time:
    Time.append(i.text)

date=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in time:
    Date.append(i.text)

# %%
 Title=Match_Title[1::2]

# %%
#printing length
print(len(Title),len(Series),len(Place),len(Time),len(Date))
# Out:
# 8 8 8 8 8

# %%
# creating data frame
df=pd.DataFrame({'Match Title': Title, "Series": Series,"Place": Place, "Date": date,"Time": Time})
df
# Out:
#                                       Match Title  \
# 0  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 1      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 2  INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 3      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 4      SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 5      SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 6      SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 7      SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
#
#                                         Series  \
# 0  India Women U19\nvs\nSouth Africa Women U19
# 1                         India\nvs\nSri Lanka
# 2  India Women U19\nvs\nSouth Africa Women U19
# 3                         India\nvs\nSri Lanka
# 4                         India\nvs\nSri Lanka
# 5                         India\nvs\nSri Lanka
# 6                         India\nvs\nSri Lanka
# 7                         India\nvs\nSri Lanka
#
#                                       Place  \
# ...

# %%
driver.close()

# %% [markdown]
# # 3.Scrape the details of selenium exception from guru99.com.

# %%
# giving url
url = 'https://www.guru99.com/'
# opening url
given_url(url)

# %%
#creating a blank list to store the scraped data
Name=[]
Description=[]

# %%
# clicking on Selenium button
selbut=driver.find_element(By.XPATH,'//li//a[@title="Selenium"]')
selbut.click()

# clicking on Exception Handling button
excp=driver.find_element(By.XPATH,'//a[@title="Selenium Exception Handling (Common Exceptions List)"]')
excp.click()

# %%
# scraping Name
name=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/p/strong')
for i in name:
    Name.append(i.text)

# %%
# scraping Description
des=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/p')
for i in des:
    Description.append(i.text)

# %%
Name=Name[:46]
Description=Description[0:46]
print(len(Description),len(Name))
# Out:
# 46 46

# %%
#printing length
print(len(Name),len(Description))

    
# creating the dataframe from the scraped data
df = pd.DataFrame({'Name':Name,'Description':Description[0:47]})
df
# Out:
# 46 46
#                                         Name  \
# 0             1. ElementNotVisibleException:
# 1          2. ElementNotSelectableException:
# 2                 3. NoSuchElementException:
# 3                   4. NoSuchFrameException:
# 4                5. NoAlertPresentException:
# 5                  6. NoSuchWindowException:
# 6         7. StaleElementReferenceException:
# 7               8. SessionNotFoundException:
# 8                       9. TimeoutException:
# 9                    10. WebDriverException:
# 10            11. ConnectionClosedException:
# 11     12. ElementClickInterceptedException:
# 12      13. ElementNotInteractableException:
# 13             14. ErrorInResponseException:
# 14  15. ErrorHandler.UnknownServerException:
# 15         16. ImeActivationFailedException:
# 16             17. ImeNotAvailableException:
# 17         18. InsecureCertificateException:
# 18             19. InvalidArgumentException:
# 19         20. InvalidCookieDomainException:
# ...

# %%
driver.close()

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.

# %%
# giving URL
url= 'http://statisticstimes.com/'
# opening url
given_url(url)

# %%
# clicking on Economy button
economy=driver.find_element(By.XPATH,'//div[@class="navbar"]/div[2]/button')
economy.click()

# clicking on India
india=driver.find_element(By.XPATH,'//div[@class="dropdown-content"]/a[3]')
india.click()


# clicking on GDP of Indian Economy
GDP = driver.find_element(By.XPATH,'//a[@class="ec"]')
GDP.click()
time.sleep(3)

# creating empty list
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# scraping Rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# scraping State
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[3]'):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    
# scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]'):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# scraping Share (18-19)
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[5]'):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# scraping GDP $ billion
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[6]'):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
    
# creating DataFrame from the scraped data
GDP = pd.DataFrame({'Rank':Rank,'State':State,'GSDP at current price (19-20)':GSDP1,'GSDP at current price (18-19)':GSDP2,'Share (18-19)':Share,'GDP($ billion)':GDP_billion})

GDP

# %%
driver.close()

# %% [markdown]
# # 5 : Scrape the details of trending repositories on Github.com.

# %%
#getting url
url='https://github.com/'
# opening url
given_url(url)

# %%
# getting explore button and clicking on it
explore = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary').click()

# selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
# creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

# fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))
    
# scraping Repository title data
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)
    
# scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(5)
    
    # scraping Repository Description data 
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # scraping Contributors Count data
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
    
    
    # scraping Languages used data
    try:
        for i in driver.find_elements_by_xpath("//ul[@class= 'list-style-none']//li//span[1]"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
        
# Data Framing
df= pd.DataFrame({'Repository Title': repository_title,'Repository Description': Description,'Contributors Count':Contributors,'Language Used':Language})
df

# %%
driver.close()

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.

# %%
#getting url
url = 'https:/www.billboard.com/'
# opening url
given_url(url)
# clicking on option button
charts=driver.find_element(By.XPATH,"//a[@class='header__main-link header__main-link--charts']").click()

view_chart=driver.find_element(By.XPATH,'//div[@class="lrv-u-flex lrv-u-justify-content-center"]')

# %%
# creating empty lists
Song_Name = []
Artist_Name =[]
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# getting urls for top 100 songs
urls = driver.find_element(By.XPATH,"//li[@class='header__submenu__list__element']//a")
page_url = urls.get_attribute("href")
driver.get(page_url)
time.sleep(4)

# scraping data of song names
for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    
# scraping data of artist names
for i in driver.find_elements(By.XPATH,"//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    
# scraping data of last week ranks
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    

# scraping data of peak ranks
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)       
    
    
# scraping data of weeks on board
for i in driver.find_elements(By.XPATH,"//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
#printing length
print(len(Song_Name),len(Artist_Name),len(Last_week_rank),len(Peak_rank),len(Weeks_on_board))

#creating dataframe
df=pd.DataFrame({'Song_Name':Song_Name,'Artist_Name':Artist_Name,'Last_week_rank':Last_week_rank,'Peak_rank':Peak_rank,'Weeks_on_board':Weeks_on_board})
df

# %%
driver.close()

# %% [markdown]
# # 7 Scrape the details of Data science recruiters from naukri.com.

# %%
# getting the webpage of mentioned url
url = "https://www.naukri.com/hr-recruiters-consultants"
# opening url
given_url(url)

# fetching search button, sending keys and clicking on it
recruiter = driver.find_element(By.XPATH,'//input[@class="sugInp"]')
recruiter.send_keys("Data Science")

search = driver.find_element(By.XPATH,'//button[@class="fl qsbSrch blueBtn"]').click()
#time.sleep(3)

# creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# scraping data of Names
for i in driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]'):
    Name.append(i.text)
    



# scraping data of Designation
for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]'):
    Designation.append(i.text)
    


# scraping data of Company Name
for i in driver.find_elements(By.XPATH,'//a[@class="ellipsis"]'):
    Company.append(i.text)
    



# scraping data of Skills
for i in driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]'):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
        



# scraping data of Location
for i in driver.find_elements(By.XPATH,'//small[@class="ellipsis"]'):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Location.append(i.text)
    except NoSuchElementException:
        Location.append('-')

# %%
# creating dataframe for scraped data
Naukri = pd.DataFrame({'Name':Name[:47],'Designation':Designation[:47],'Company':Company[:47],'Skills':Skills[:47],'Location':Location[:47]})
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                             Vaishnavi Kudalkar
# 15                                 Priyanka Akiri
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()

# %% [markdown]
# # 8. scrap deatils of highest selling novel

# %%
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
# opening url
given_url(url)
#creating a blank list 
Rank=[]
Book=[]
Author=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# get web elements
rank_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[1]")
for i in rank_wbe:
    Rank.append(i.text)
bname_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in bname_wbe:
    Book.append(i.text)
auth_name_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in auth_name_wbe:
    Author.append(i.text)

vols_sold_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in vols_sold_wbe:
    Volumes_sold.append(i.text)
publisher_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in publisher_wbe:
    Publisher.append(i.text)
genre_wbe = driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in genre_wbe:
    Genre.append(i.text)

# %%
#printing length
print(len(Rank),len(Book),len(Author),len(Volumes_sold),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100 100

# %%
#creating dataframe
df=pd.DataFrame({'Rank':Rank,'Book name':Book,'Volumes_sold':Volumes_sold,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#    Rank                                          Book name Volumes_sold  \
# 0     1                                  Da Vinci Code,The    5,094,805
# 1     2               Harry Potter and the Deathly Hallows    4,475,152
# 2     3           Harry Potter and the Philosopher's Stone    4,200,654
# 3     4          Harry Potter and the Order of the Phoenix    4,179,479
# 4     5                               Fifty Shades of Grey    3,758,936
# ..  ...                                                ...          ...
# 95   96                                          Ghost,The      807,311
# 96   97                     Happy Days with the Naked Chef      794,201
# 97   98              Hunger Games,The:Hunger Games Trilogy      792,187
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      791,507
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...      791,095
#
#           Publisher                        Genre
# 0        Transworld  Crime, Thriller & Adventure
# ...

# %%
driver.close()

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.

# %%
url='https://www.imdb.com/list/ls095964455/'
#opening url
given_url(url)
#creating a blank list
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]
# getting weeb element
name=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/a')
for i in name:
    Name.append(i.text)
    
yr=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/h3/span[2]')
for i in yr:
    Year_span.append(i.text)
    
genre=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[@class="text-muted text-small"]/span[@class="genre"]')
for i in genre:
    Genre.append(i.text)
    
run=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[@class="text-muted text-small"]/span[@class="runtime"]')
for i in run:
    Run_time.append(i.text)
    
rating=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[@class="ipl-rating-star__rating"]')
for i in rating:
    Ratings.append(i.text)
    
votes=driver.find_elements(By.XPATH,'//div[@class="lister-item-content"]/p[@class="text-muted text-small"]/span[@name="nv"]')
for i in votes:
    Votes.append(i.text)

# %%
# printing length
print(len(Name),len(Year_span),len(Genre),len(Run_time),len(Ratings),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
#creating dataframe
df=pd.DataFrame({'Name':Name,'Year_span':Year_span,'Genre':Genre,'Run_time':Run_time,'Ratings':Ratings,'Votes':Votes})
df
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  2,100,183
# ...

# %%
driver.close()

# %% [markdown]
# # 10. scrap the details of Datasets from UCI machine learning repositories.

# %%
# giving url
url = 'https://archive.ics.uci.edu/'

#opening url
given_url(url)

#click on "view all repositories"
driver.find_element(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a').click()

#creating a blank list

Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

#getting webelements
name=driver.find_elements(By.XPATH,'//span[@class="heading"]')
for i in name:
    Dataset_name.append(name.text)
    
data=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr/td[2]')
for i in name:
    Data_type.append(data.text)
    
task=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr[3]/td[2]')
for i in name:
    Task.append(task.text)
    
attribute=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr[2]/td[2]')
for i in name:
    Attribute_type.append(attribute.text)
    
inst=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr/td[4]')
for i in name:
    No_of_instances.append(inst.text)
    
atr=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr[2]/td[4]')
for i in name:
    No_of_attribute.append(atr.text)
    
year=driver.find_elements(By.XPATH,'//table[@border="1"]//tbody/tr[2]/td[6]')
for i in name:
    Year.append(year.text)

# %%
#printing length
print(len(Dataset_name),len(Data_type),len(Task),len(Attribute_type),len(No_of_instances),len(No_of_attribute),len(Year))

# %%
#creating a dataframe
df=pd.DataFrame({'Dataset_name':Dataset_name,'Data_type':Data_type,'Task':Task,'Attribute_type':Attribute_type,'No_of_instances':No_of_instances,'No_of_attribute':No_of_attribute,'Year':Year})
df
